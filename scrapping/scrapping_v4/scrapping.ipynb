# %%
import requests
import pandas as pd

# %%
API_KEY = "mNm8lpEUIbPzJu5gHu9ieAtt"

url = "https://wikirate.org/Clean_Clothes_Campaign+Living_Wage_Action_Plan+Answer.json"
headers = {"User-Agent": "FashionEthicsDataBot/1.0"}

params = {
    "limit": 100,
    "api_key": API_KEY
}

# %%
response2 = response

# %%
print("🔍 Recherche des métriques contenant 'Living wage paid'...")
response = requests.get(url, headers=headers, params=params)
print("Status:", response.status_code)
# Out:
# 🔍 Recherche des métriques contenant 'Living wage paid'...
# Status: 200

# %%
for a in response.json()['items']:
    print(f"{a['company']}  - {a['value']}")
# Out:
# Varusteleka Oy  - No
# Halti Oy  - No
# Joutsen Finland Oy  - No
# Finlayson Oy  - No
# Makia Clothing Oy  - No
# Devold of Norway AS  - Yes
# Nanso Group Oy  - No
# Reima  - No
# Marimekko  - No
# SOK S Group  - No
# Lindex  - No
# Stockmann Oyj Abp  - No
# Kesko Corporation  - No
# Tokmanni  - No
# Luhta Sportswear Company  - Yes
# Hema  - Yes
# Zeeman  - Yes
# Schijvens  - No
# Artsana S.p.A.  - No
# JBC NV  - No
# Reima  - Partial
# Geox SpA  - No
# Hunkemoller  - Partial
# The Sting B.V.  - No
# We Europe BV  - Partial
# Marimekko  - No
# Wibra Supermarkt B.V.  - No
# Zeeman  - Yes
# Van de Velde  - No
# The Iconic  - Yes
# The Just Group  - Partial
# Country Road Group  - Partial
# LaDress  - No
# Schijvens  - Partial
# Mayerline  - No
# Kings Of Indigo  - No
# Cassis / Paprika S.A.  - No
# Kuyichi  - Partial
# Scotch and Soda  - No
# Kesko Corporation  - No
# Peek & Cloppenburg  - No
# Tokmanni  - No
# e5 mode  - No
# Vaude  - No
# Fabrimode NV  - No
# Oberalp SpA  - Yes
# PP Retail Group  - No
# Luhta Sportswear Company  - No
# Naura Group B.V.  - No
# Falc S.p.a.  - No
# Sogesma SA  - No
# ZEB (The Fashion Society NV)  - No
# Veritas NV  - No
# Daily Paper Holding B.V.  - No
# Wehkamp Retail Group Holding B.V.  - No
# Chiquelle AB  - No
# Essentiel Antwerp  - No
# NA-KD (Nakdcom One World AB)  - No
# BEST & LESS GROUP PTY LTD  - No
# FOREVER NEW CLOTHING PTY LTD  - Yes
# MOSAIC BRANDS LIMITED  - Yes
# Livera B.V.  - No
# Prenatal Moeder en Kind B.V.  - No
# Sogesma SA  - No
# JBC NV  - No
# Missguided Limited  - No
# Reima  - No
# Naura Group B.V.  - No
# Geox SpA  - No
# ZEB (The Fashion Society NV)  - No
# The Sting B.V.  - No
# We Europe BV  - Partial
# Veritas NV  - No
# Daily Paper Holding B.V.  - No
# Marimekko  - No
# Wibra Supermarkt B.V.  - No
# Chiquelle AB  - No
# NA-KD (Nakdcom One World AB)  - No
# Van de Velde  - No
# The Iconic  - No
# BEST & LESS GROUP PTY LTD  - Partial
# Country Road Group  - No
# FOREVER NEW CLOTHING PTY LTD  - Partial
# LaDress  - No
# MOSAIC BRANDS LIMITED  - Partial
# Gymshark Limited  - No
# Prenatal Moeder en Kind B.V.  - Partial
# Mayerline  - No
# Kings Of Indigo  - No
# Cassis / Paprika S.A.  - No
# Tokmanni  - No
# PP Retail Group  - No
# Peek & Cloppenburg  - No
# Kesko Corporation  - No
# BALR. BV  - No
# Artsana S.p.A.  - No
# NP Fashion  - No
# Essentiel Antwerp  - No
# Fabrimode NV  - No
# ECG nv  - No

# %%
for a in response.json()['items']:
    if a['designer'] == "Clean Clothes Campaign":
        print(a)
